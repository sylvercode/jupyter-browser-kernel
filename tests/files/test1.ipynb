// %% [markdown]
// # Success Contract Tests
//
// Expected: Output is `4` only.

// %%
2 + 2
// Out:
// 4

// %% [markdown]
// Expected: Output is `hello` only (no JSON wrapper).

// %%
"hello"
// Out:
// hello

// %% [markdown]
// Expected: Output is `true`

// %%
true
// Out:
// true

// %% [markdown]
// Expected: Output is `null`.

// %%
null
// Out:
// null

// %% [markdown]
// Expected: Output is `undefined`.

// %%
undefined
// Out:
// undefined

// %% [markdown]
// Expected: Output is `Infinity`.

// %%
Infinity
// Out:
// Infinity

// %% [markdown]
// Expected: Output is `NaN`.

// %%
NaN
// Out:
// NaN

// %% [markdown]
// Expected: Output is `-0`.

// %%
-0
// Out:
// -0

// %% [markdown]
// Expected: Output is `123n`.

// %%
123n
// Out:
// 123n

// %% [markdown]
// Expected: Output is `[1,2,3]`.

// %%
[1, 2, 3]
// Out:
// [1,2,3]

// %% [markdown]
// Expected: Output is `{"a":1,"b":"two"}`.

// %%
({ a: 1, b: "two" })
// Out:
// {"a":1,"b":"two"}

// %% [markdown]
// Expected: Output appears empty, and execution succeeds (no error).

// %%
""
// Out:
// undefined

// %% [markdown]
// # Failure Contract Tests
//
// Expected: Structured error with `name=TypeError` and `message=boom`.

// %%
throw new TypeError("boom")
// Out:
// TypeError: boom
//
//     at cell.js:1:7

// %% [markdown]
// Expected: Structured error with `name=TypeError` and `message=boom`.

// %%
await Promise.reject(new TypeError("boom"))
// Out:
// TypeError: boom
//
//     at cell.js:1:22

// %% [markdown]
// Expected: Structured syntax failure.

// %%
let x = ;
// Out:
// SyntaxError: Unexpected token ';'
//
// 	at toErrorObject (file:///workspaces/foundry-devil-code-sight/dist/extension.mjs:1398:17)
//
// 	at writeFailureOutput (file:///workspaces/foundry-devil-code-sight/dist/extension.mjs:1390:17)
//
// 	at executeCell (file:///workspaces/foundry-devil-code-sight/dist/extension.mjs:1320:11)
//
// 	at process.processTicksAndRejections (node:internal/process/task_queues:103:5)
//
// 	at async controller.executeHandler (file:///workspaces/foundry-devil-code-sight/dist/extension.mjs:1427:28)
//
// 	at async Vh.$executeCells (file:///vscode/vscode-server/bin/linux-x64/560a9dba96f961efea7b1612916f89e5d5d4d679/out/vs/workbench/api/node/extensionHostProcess.js:639:28140)

// %% [markdown]
// Expected: Plain text infrastructure failure message, not raw protocol details.

// %%
await new Promise(() => {})
// Out:
// No active browser session. Run Jupyter Browser Kernel: Reconnect and try again.
