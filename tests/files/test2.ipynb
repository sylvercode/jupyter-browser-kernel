# %%
function addOne(n) {
    const result = n + 1;
    return result;
}

const x = 1;
const y = addOne(x);
y;
# Out:
# 2

# %%
function c() { debugger; return 3; }
function b() { return c(); }
function a() { return b(); }
a();

# %%
// Simple call (steppable in both VS Code and DevTools)
add(3, 4)

// Multi-step function (set breakpoints on individual lines in VS Code)
runDemo()

// Object inspection (useful for variable/scope pane testing)
inspect({ x: 1, y: [2, 3], z: { nested: true } })
# Out:
# {"obj":{"x":1,"y":[2,3],"z":{"nested":true}},"keys":["x","y","z"],"count":3}
